# %%
# !git clone https://github.com/sooryaveeravalli/CS520-IE2-Triangle.git
# Out:
# Cloning into 'CS520-IE2-Triangle'...
# remote: Enumerating objects: 135, done.
# remote: Counting objects: 100% (68/68), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 135 (delta 58), reused 52 (delta 45), pack-reused 67 (from 1)
# Receiving objects: 100% (135/135), 279.22 KiB | 7.16 MiB/s, done.
# Resolving deltas: 100% (74/74), done.

# %%
pwd
# Out:
# '/content'

# %%
cd CS520-IE2-Triangle/
# Out:
# /content/CS520-IE2-Triangle

# %%
ls
# Out:
# decision_coverage.sh*        mutation.sh       statement_coverage.sh
# isTriangle_cfg_numbered.png  README.md         test.sh
# isTriangle_cfg_numbered.svg  requirements.txt  test_suit/

# %%
# !chmod +x test.sh
# !chmod +x statement_coverage.sh
# !chmod +x decision_coverage.sh
# !chmod +x mutation.sh

# %%
# !pip install -r requirements.txt
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 11.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.1/325.1 kB 22.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.1/133.1 kB 9.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.6/102.6 kB 8.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 757.7/757.7 kB 28.0 MB/s eta 0:00:00
# ...
#   Created wheel for astmonkey: filename=astmonkey-0.3.6-py3-none-any.whl size=10429 sha256=646ee1d8c66db21cf250c492291741736a88da1c4a27396c649c11cafbca073f
#   Stored in directory: /root/.cache/pip/wheels/0b/40/5a/9a71ac3af4c6e3254bfb9d6b3b3844e22855f654457ab9461d
# Successfully built astmonkey
# ...
#   Attempting uninstall: termcolor
#     Found existing installation: termcolor 2.5.0
#     Uninstalling termcolor-2.5.0:
#       Successfully uninstalled termcolor-2.5.0
#   Attempting uninstall: PyYAML
# ...

# %%
# !sh test.sh
# Out:
# ======================================= test session starts ========================================
# platform linux -- Python 3.11.11, pytest-7.4.3, pluggy-1.5.0
# rootdir: /content/CS520-IE2-Triangle/test_suit
# plugins: langsmith-0.3.18, anyio-4.9.0, typeguard-4.4.2
# collected 1 item
#
# test_triangle.py .                                                                           [100%]
#
# ======================================== 1 passed in 0.04s =========================================
# Name               Stmts   Miss  Cover   Missing
# ------------------------------------------------
# test_triangle.py       9      1    89%   14
# ------------------------------------------------
# TOTAL                  9      1    89%
# Wrote HTML report to initial_statement_html/index.html
# .
# ----------------------------------------------------------------------
# Ran 1 test in 0.000s
#
# OK
# Name               Stmts   Miss Branch BrPart  Cover   Missing
# ...

# %%
# !sh statement_coverage.sh
# Out:
# ======================================= test session starts ========================================
# platform linux -- Python 3.11.11, pytest-7.4.3, pluggy-1.5.0
# rootdir: /content/CS520-IE2-Triangle/test_suit
# plugins: langsmith-0.3.18, anyio-4.9.0, typeguard-4.4.2
# collected 8 items
#
# test_statementCoverage.py ........                                                           [100%]
#
# ======================================== 8 passed in 0.11s =========================================
# Name                        Stmts   Miss  Cover   Missing
# ---------------------------------------------------------
# test_statementCoverage.py      37      1    97%   55
# ---------------------------------------------------------
# TOTAL                          37      1    97%
# Wrote HTML report to statement_html/index.html

# %%
# !sh decision_coverage.sh
# Out:
# ........
# ----------------------------------------------------------------------
# Ran 8 tests in 0.001s
#
# OK
# Name                       Stmts   Miss Branch BrPart  Cover   Missing
# ----------------------------------------------------------------------
# test_decisionCoverage.py      37      0      2      1    97%   61->exit
# ----------------------------------------------------------------------
# TOTAL                         37      0      2      1    97%
# Wrote HTML report to decision_html/index.html

# %%
# !sh mutation.sh
# Out:
# [*] Start mutation process:
#    - targets: isTriangle
#    - tests: test_mutationAdequate
# [*] 5 tests passed:
#    - test_mutationAdequate [0.00044 s]
# [*] Start mutants generation and execution:
#    - [#   1] AOR isTriangle:
# --------------------------------------------------------------------------------
#   30:         if b == c:
#   31:             trian += 3
#   32:
#   33:         if trian == 0:
# - 34:             if (a + b <= c or a + c <= b or b + c <= a):
# + 34:             if (a - b <= c or a + c <= b or b + c <= a):
#   35:                 return Triangle.Type.INVALID
#   36:             else:
#   37:                 return Triangle.Type.SCALENE
#   38:
# --------------------------------------------------------------------------------
# [0.00977 s] killed by test_floating_point_values (test_mutationAdequate.TriangleMutationTest.test_floating_point_values)
#    - [#   2] AOR isTriangle:
# ...
